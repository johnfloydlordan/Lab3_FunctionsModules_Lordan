# %%
# IMPORT

import access_control
import signal_shutdown
import media_engine

# %%
# STUDENT CONFIG

SEED_NUM = 2
FAVORITE_ARTIST = "THE RIDLEYS"
CONTROL_NUM = max(1, SEED_NUM)

# %%
# MISSION 1: AUTHORIZATION
print("=" * 50)
print("MISSION 1: AUTHORIZATION PROTOCOL")
print("=" * 50)

decision = access_control.authorize(CONTROL_NUM, FAVORITE_ARTIST)
print("Final Authorization Decision:", decision)
# Out:
# ==================================================
# MISSION 1: AUTHORIZATION PROTOCOL
# ==================================================
# Authorization Started
# Authorization Completed
# Final Authorization Decision: ACCESS GRANTED

# %%
# MISSION 2: RECURSIVE SHUTDOWN
print("\n" + "=" * 50)
print("MISSION 2: RECURSIVE SIGNAL SHUTDOWN")
print("=" * 50)

initial_power = CONTROL_NUM + len(FAVORITE_ARTIST)
print("Initial Signal Strength:", initial_power)

total_calls = signal_shutdown.signal_shutdown(initial_power)
print("Total Recursive Calls:", total_calls)
# Out:
# ==================================================
# MISSION 2: RECURSIVE SIGNAL SHUTDOWN
# ==================================================
# Initial Signal Strength: 13
# Authorization Started
# Signal Strength: 13
# Authorization Started
# Signal Strength: 12
# Authorization Started
# Signal Strength: 11
# Authorization Started
# Signal Strength: 10
# Authorization Started
# Signal Strength: 9
# Authorization Started
# Signal Strength: 8
# Authorization Started
# Signal Strength: 7
# Authorization Started
# Signal Strength: 6
# Authorization Started
# Signal Strength: 5
# Authorization Started
# Signal Strength: 4
# Authorization Started
# Signal Strength: 3
# Authorization Started
# Signal Strength: 2
# Authorization Started
# Signal Strength: 1
# Authorization Started
# Authorization Completed
# Authorization Completed
# Authorization Completed
# Authorization Completed
# Authorization Completed
# Authorization Completed
# Authorization Completed
# Authorization Completed
# Authorization Completed
# Authorization Completed
# Authorization Completed
# Authorization Completed
# Authorization Completed
# Authorization Completed
# Total Recursive Calls: 13

# %%
# MISSION 3: STREAMING ANALYTICS
print("\n" + "=" * 50)
print("MISSION 3: STREAMING MEDIA ENGINE")
print("=" * 50)

limit = CONTROL_NUM + len(FAVORITE_ARTIST)
print("Stream Limit:", limit)

media_engine.play_count_stream(limit)
# Out:
# ==================================================
# MISSION 3: STREAMING MEDIA ENGINE
# ==================================================
# Stream Limit: 13
# Processing Started
# Play Count: 0
# Play Count: 4
# Play Count: 16
# Play Count: 36
# Play Count: 64
# Play Count: 100
# Play Count: 144
# Total Plays: 364
# Number of Records Processed: 7
# Processing Completed
# 364
